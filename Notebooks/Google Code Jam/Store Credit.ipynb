# %% [markdown]
# ## Challenge 2: Store Credit
#
# Challenge Url: https://code.google.com/codejam/contest/dashboard?c=351101
#
# You receive a credit C at a local store and would like to buy two items. You first walk through the store and create a list L of all available items. From this list you would like to buy two items that add up to the entire value of the credit. The solution you provide will consist of the two integers indicating the positions of the items in your list (smaller number first).
#
# ### Input
#
# The first line of input gives the number of cases, N. N test cases follow. For each test case there will be:
#
# * One line containing the value C, the amount of credit you have at the store.
# * One line containing the value I, the number of items in the store.
# * One line containing a space separated list of I integers. Each integer P indicates the price of an item in the store.
# Each test case will have exactly one solution.
#
# ### Output
#
# For each test case, output one line containing "Case #x: " followed by the indices of the two items whose price adds up to the store credit. The lower index should be output first.
#
# ### Limits - Small dataset
#
# 5 ≤ C ≤ 1000
# 1 ≤ P ≤ 1000
# N = 10
# 3 ≤ I ≤ 100
#
# ### Limits - Large dataset
#
# 5 ≤ C ≤ 1000
# 1 ≤ P ≤ 1000
# N = 50
# 3 ≤ I ≤ 2000
#
# ### Sample:
#
# Input:
#
# 3
# 100
# 3
# 5 75 25
# 200
# 7
# 150 24 79 50 88 345 3
# 8
# 8
# 2 1 9 4 4 56 90 3
#
# Output:
# Case #1: 2 3
# Case #2: 1 4
# Case #3 4 5

# %%
def store_credit(f_path):
    print 'Procesing Input [%s]' % f_path

    # File Handling
    with open(f_path, 'r') as f_reader:
        # Number of Test Cases
        test_cases = int(f_reader.readline())

        test_case = 1
        while test_case <= test_cases:

            # Reading next 3 Lines
            store_credit = int(f_reader.readline())
            products_count = int(f_reader.readline())
            product_prices = f_reader.readline()

            # Converting array of strings to array of ints
            product_prices = map(lambda x: int(x), product_prices.split(' '))

            # Array Indexes used to navigate through
            anchor_idx, current_idx, found_sum, price_too_high = 0, 0, False, False

            print 'Test Case #%d' % test_case

            # Iterating over list elements
            while anchor_idx < products_count and not found_sum:

                # Avoids having to iterate through the array
                current_idx = anchor_idx + 1
                while current_idx < products_count:

                    # Summing
                    anchor_price = product_prices[anchor_idx]
                    current_price = product_prices[current_idx] 
                    products_sum = anchor_price + current_price

                    # Code Optimization (If the Anchor Value is already greater than the sum value itself, there's no reason to keep trying to sum it with the next values)
                    if anchor_price > store_credit:
                        break

                    # Have we found the sum ?
                    if products_sum == store_credit:
                        print 'Found the sum: %d + %d = %d' % (anchor_price, current_price, products_sum)

                        # Writing result to output file
                        output_line = 'Case #%d Answer: %d %d\n'
                        if anchor_idx < current_idx:
                            print output_line % (test_case, anchor_idx + 1, current_idx + 1)
                        else:
                            print output_line % (test_case, current_idx + 1, anchor_idx + 1);
                        found_sum = True
                        break

                    current_idx = current_idx + 1         
                anchor_idx = anchor_idx + 1            
            test_case = test_case + 1

# %%
# Running StoreCredit Test Cases
store_credit('Input/store_credit_small.in')
store_credit('Input/store_credit_large.in')
# Out:
# Procesing Input [Input/store_credit_small.in]
# Test Case #1
# Found the sum: 75 + 25 = 100
# Case #1 Answer: 2 3
#
# Test Case #2
# Found the sum: 150 + 50 = 200
# Case #2 Answer: 1 4
#
# Test Case #3
# Found the sum: 4 + 4 = 8
# Case #3 Answer: 4 5
#
# Test Case #4
# Found the sum: 221 + 321 = 542
# Case #4 Answer: 29 46
#
# Test Case #5
# Found the sum: 104 + 685 = 789
# Case #5 Answer: 11 56
#
# Test Case #6
# Found the sum: 54 + 47 = 101
# Case #6 Answer: 4 5
#
# Test Case #7
# Found the sum: 9 + 26 = 35
# Case #7 Answer: 40 46
#
# Test Case #8
# Found the sum: 292 + 598 = 890
# Case #8 Answer: 16 35
#
# Test Case #9
# Found the sum: 48 + 115 = 163
# Case #9 Answer: 55 74
#
# Test Case #10
# Found the sum: 118 + 177 = 295
# Case #10 Answer: 7 9
#
# Procesing Input [Input/store_credit_large.in]
# Test Case #1
# Found the sum: 75 + 25 = 100
# Case #1 Answer: 2 3
#
# Test Case #2
# Found the sum: 150 + 50 = 200
# Case #2 Answer: 1 4
#
# Test Case #3
# Found the sum: 4 + 4 = 8
# Case #3 Answer: 4 5
#
# Test Case #4
# Found the sum: 221 + 321 = 542
# Case #4 Answer: 29 46
#
# Test Case #5
# Found the sum: 104 + 685 = 789
# Case #5 Answer: 11 56
#
# Test Case #6
# Found the sum: 47 + 54 = 101
# Case #6 Answer: 84 240
#
# Test Case #7
# Found the sum: 207 + 722 = 929
# Case #7 Answer: 413 584
#
# Test Case #8
# Found the sum: 566 + 152 = 718
# Case #8 Answer: 28 80
#
# Test Case #9
# Found the sum: 7 + 21 = 28
# Case #9 Answer: 380 633
#
# Test Case #10
# Found the sum: 32 + 42 = 74
# Case #10 Answer: 190 242
#
# Test Case #11
# Found the sum: 368 + 102 = 470
# Case #11 Answer: 450 667
#
# Test Case #12
# Found the sum: 159 + 21 = 180
# Case #12 Answer: 7 126
#
# Test Case #13
# Found the sum: 115 + 435 = 550
# Case #13 Answer: 208 636
#
# Test Case #14
# Found the sum: 63 + 458 = 521
# Case #14 Answer: 301 831
#
# Test Case #15
# Found the sum: 311 + 168 = 479
# Case #15 Answer: 243 649
#
# Test Case #16
# Found the sum: 75 + 166 = 241
# Case #16 Answer: 258 429
#
# Test Case #17
# Found the sum: 111 + 101 = 212
# Case #17 Answer: 18 49
#
# Test Case #18
# Found the sum: 292 + 73 = 365
# Case #18 Answer: 7 32
#
# Test Case #19
# Found the sum: 92 + 456 = 548
# Case #19 Answer: 750 965
#
# Test Case #20
# Found the sum: 89 + 35 = 124
# Case #20 Answer: 196 718
#
# Test Case #21
# Found the sum: 530 + 147 = 677
# Case #21 Answer: 292 1236
#
# Test Case #22
# Found the sum: 103 + 612 = 715
# Case #22 Answer: 539 935
#
# Test Case #23
# Found the sum: 738 + 104 = 842
# Case #23 Answer: 20 263
#
# Test Case #24
# Found the sum: 814 + 18 = 832
# Case #24 Answer: 30 107
#
# Test Case #25
# Found the sum: 432 + 253 = 685
# Case #25 Answer: 3 94
#
# Test Case #26
# Found the sum: 284 + 598 = 882
# Case #26 Answer: 425 484
#
# Test Case #27
# Found the sum: 197 + 749 = 946
# Case #27 Answer: 623 923
#
# Test Case #28
# Found the sum: 222 + 581 = 803
# Case #28 Answer: 219 656
#
# Test Case #29
# Found the sum: 158 + 304 = 462
# Case #29 Answer: 133 242
#
# Test Case #30
# Found the sum: 738 + 88 = 826
# Case #30 Answer: 691 800
#
# Test Case #31
# Found the sum: 551 + 267 = 818
# Case #31 Answer: 317 338
#
# Test Case #32
# Found the sum: 453 + 468 = 921
# Case #32 Answer: 207 485
#
# Test Case #33
# Found the sum: 63 + 73 = 136
# Case #33 Answer: 63 64
#
# Test Case #34
# Found the sum: 132 + 94 = 226
# Case #34 Answer: 13 206
#
# Test Case #35
# Found the sum: 15 + 57 = 72
# Case #35 Answer: 407 421
#
# Test Case #36
# Found the sum: 50 + 827 = 877
# Case #36 Answer: 654 972
#
# Test Case #37
# Found the sum: 606 + 32 = 638
# Case #37 Answer: 205 275
#
# Test Case #38
# Found the sum: 6 + 478 = 484
# Case #38 Answer: 499 883
#
# Test Case #39
# Found the sum: 25 + 41 = 66
# Case #39 Answer: 471 633
#
# Test Case #40
# Found the sum: 43 + 470 = 513
# Case #40 Answer: 371 393
#
# Test Case #41
# Found the sum: 55 + 311 = 366
# Case #41 Answer: 25 170
#
# Test Case #42
# Found the sum: 308 + 41 = 349
# Case #42 Answer: 64 521
#
# Test Case #43
# Found the sum: 711 + 188 = 899
# Case #43 Answer: 28 78
#
# Test Case #44
# Found the sum: 22 + 543 = 565
# Case #44 Answer: 949 1590
#
# Test Case #45
# Found the sum: 534 + 408 = 942
# Case #45 Answer: 1 1043
#
# Test Case #46
# Found the sum: 103 + 438 = 541
# Case #46 Answer: 636 773
#
# Test Case #47
# Found the sum: 168 + 386 = 554
# Case #47 Answer: 240 908
#
# Test Case #48
# Found the sum: 781 + 102 = 883
# Case #48 Answer: 6 47
#
# Test Case #49
# Found the sum: 640 + 217 = 857
# Case #49 Answer: 81 288
#
# Test Case #50
# Found the sum: 231 + 61 = 292
# Case #50 Answer: 274 983
